# %%
import requests
import pandas as pd
from io import BytesIO
from datetime import datetime
import calendar

# %%
start_year = 2023
end_year = datetime.now().year

for year in range(start_year, end_year + 1):
    start_month = 1
    end_month = 12
    if year == end_year:
        end_month = datetime.now().month

    for month in range(start_month, end_month + 1):
        month_name = calendar.month_name[month]  # Get full month name
        print(f"Year: {year}, Month: {month_name}")
# Out:
# Year: 2023, Month: January
# Year: 2023, Month: February
# Year: 2023, Month: March
# Year: 2023, Month: April
# Year: 2023, Month: May
# Year: 2023, Month: June
# Year: 2023, Month: July
# Year: 2023, Month: August
# Year: 2023, Month: September
# Year: 2023, Month: October
# Year: 2023, Month: November
# Year: 2023, Month: December
# Year: 2024, Month: January
# Year: 2024, Month: February
# Year: 2024, Month: March
# Year: 2024, Month: April
# Year: 2024, Month: May
# Year: 2024, Month: June
# Year: 2024, Month: July
# Year: 2024, Month: August
# Year: 2024, Month: September
# Year: 2024, Month: October
# Year: 2024, Month: November
# Year: 2024, Month: December
# Year: 2025, Month: January
# Year: 2025, Month: February
# Year: 2025, Month: March
# Year: 2025, Month: April
# Year: 2025, Month: May
# Year: 2025, Month: June
# Year: 2025, Month: July
# Year: 2025, Month: August
# Year: 2025, Month: September
# Year: 2025, Month: October
# Year: 2025, Month: November

# %%
url = 'https://data.wprdc.org/dataset/f376ccbc-c851-4b58-8b59-5dd9edc736ee/resource/a27865cf-5621-43f9-9ee9-06f65ba9d544/download/september-2025.xlsx'

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
response
# Out:
# <Response [200]>

# %%
df = pd.read_excel(BytesIO(response.content))

# %%
df
# Out:
#        Closed Status  Duration  Start Station Id          Start Date  \
# 0             NORMAL      7310                38 2025-09-30 23:59:25
# 1             NORMAL       272                13 2025-09-30 23:57:33
# 2             NORMAL       412                11 2025-09-30 23:57:12
# 3             NORMAL       170                13 2025-09-30 23:57:03
# 4             NORMAL       293                13 2025-09-30 23:57:03
# ...              ...       ...               ...                 ...
# 101193        NORMAL       319                13 2025-09-01 00:07:37
# 101194        NORMAL       350                13 2025-09-01 00:06:55
# 101195        NORMAL       279                34 2025-09-01 00:06:10
# 101196        NORMAL       165                38 2025-09-01 00:01:47
# 101197        NORMAL       325                34 2025-09-01 00:00:05
#
#                   Start Station Name            End Date  End Station Id  \
# ...
