# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
df = pd.read_parquet('./data/combined data/data.parquet')

# %%
df
# Out:
#        Closed Status  Duration  Start Station Id          Start Date  \
# 0             NORMAL       257                13 2023-04-30 23:54:00
# 1             NORMAL       351                13 2023-04-30 10:21:00
# 2             NORMAL       310                13 2023-04-30 03:59:00
# 3             NORMAL       408                13 2023-04-30 00:44:00
# 4             NORMAL       417                13 2023-04-29 09:19:00
# ...              ...       ...               ...                 ...
# 387225        NORMAL      1886                43 2023-09-05 20:04:09
# 387226        NORMAL       242                42 2024-04-29 15:39:00
# 387227        NORMAL       646                42 2024-04-09 18:06:00
# 387228        NORMAL       776                42 2024-01-26 11:40:26
# 387229        NORMAL       247                42 2023-09-01 18:37:29
#
#                 Start Station Name            End Date  End Station Id  \
# 0       S Bouquet Ave & Sennott St 2023-04-30 23:59:00              34
# 1       S Bouquet Ave & Sennott St 2023-04-30 10:27:00              34
# 2       S Bouquet Ave & Sennott St 2023-04-30 04:04:00              34
# 3       S Bouquet Ave & Sennott St 2023-04-30 00:50:00              34
# 4       S Bouquet Ave & Sennott St 2023-04-29 09:26:00              34
# ...                            ...                 ...             ...
# 387225         Eliza St & Lytle St 2023-09-05 20:35:35              43
# 387226    Second Ave & Tecumseh St 2024-04-29 15:43:00              43
# 387227    Second Ave & Tecumseh St 2024-04-09 18:16:00              43
# 387228    Second Ave & Tecumseh St 2024-01-26 11:53:22              43
# 387229    Second Ave & Tecumseh St 2023-09-01 18:41:36              43
#
#                    End Station Name Rider Type  Start Station Total Docks  \
# 0       N Dithridge St & Centre Ave     MEMBER                         23
# 1       N Dithridge St & Centre Ave     MEMBER                         23
# 2       N Dithridge St & Centre Ave     MEMBER                         23
# 3       N Dithridge St & Centre Ave     MEMBER                         23
# 4       N Dithridge St & Centre Ave     MEMBER                         23
# ...                             ...        ...                        ...
# 387225          Eliza St & Lytle St     CASUAL                         19
# 387226          Eliza St & Lytle St     MEMBER                         19
# 387227          Eliza St & Lytle St     MEMBER                         19
# 387228          Eliza St & Lytle St     MEMBER                         19
# 387229          Eliza St & Lytle St     MEMBER                         19
#
#         Start Station Latitude  Start Station Longitude  \
# 0                    40.441638               -79.955764
# 1                    40.441638               -79.955764
# 2                    40.441638               -79.955764
# 3                    40.441638               -79.955764
# 4                    40.441638               -79.955764
# ...                        ...                      ...
# 387225               40.413481               -79.948254
# 387226               40.408857               -79.943684
# 387227               40.408857               -79.943684
# 387228               40.408857               -79.943684
# 387229               40.408857               -79.943684
#
#        Start Station Neighborhood  End Station Total Docks  \
# 0                 Central Oakland                       19
# 1                 Central Oakland                       19
# 2                 Central Oakland                       19
# 3                 Central Oakland                       19
# 4                 Central Oakland                       19
# ...                           ...                      ...
# 387225                  Hazelwood                       19
# 387226                  Hazelwood                       19
# 387227                  Hazelwood                       19
# 387228                  Hazelwood                       19
# 387229                  Hazelwood                       19
#
#         End Station Latitude  End Station Longitude End Station Neighborhood  \
# 0                  40.451281             -79.952982            North Oakland
# 1                  40.451281             -79.952982            North Oakland
# 2                  40.451281             -79.952982            North Oakland
# 3                  40.451281             -79.952982            North Oakland
# 4                  40.451281             -79.952982            North Oakland
# ...                      ...                    ...                      ...
# 387225             40.413481             -79.948254                Hazelwood
# 387226             40.413481             -79.948254                Hazelwood
# 387227             40.413481             -79.948254                Hazelwood
# 387228             40.413481             -79.948254                Hazelwood
# 387229             40.413481             -79.948254                Hazelwood
#
#         Trip Distance (km)       Trip Time
# 0                 1.096491 0 days 00:05:00
# 1                 1.096491 0 days 00:06:00
# 2                 1.096491 0 days 00:05:00
# 3                 1.096491 0 days 00:06:00
# 4                 1.096491 0 days 00:07:00
# ...                    ...             ...
# 387225            0.000000 0 days 00:31:26
# 387226            0.643509 0 days 00:04:00
# 387227            0.643509 0 days 00:10:00
# 387228            0.643509 0 days 00:12:56
# 387229            0.643509 0 days 00:04:07
#
# [387230 rows x 19 columns]

# %%
df['Month'] = df['Start Date'].dt.month
df['Year'] = df['Start Date'].dt.year

# %%
monthly_riders = df.groupby(['Year', 'Month']).size().reset_index(name='Monthly Riders')

# %%
monthly_riders
# Out:
#     Year  Month  Monthly Riders
# 0   2022      5            6097
# 1   2022      6            9264
# 2   2022      7            9052
# 3   2022      8           11275
# 4   2022      9           14115
# 5   2022     10           11317
# 6   2022     11            7417
# 7   2022     12            3690
# 8   2023      1            3825
# 9   2023      2            5685
# 10  2023      3            5839
# 11  2023      4           11343
# 12  2023      5           11975
# 13  2023      6           13505
# 14  2023      7           18202
# 15  2023      8           23841
# 16  2023      9           36865
# 17  2023     10           38077
# 18  2023     11           25795
# 19  2023     12           16135
# 20  2024      1           14437
# 21  2024      2           25341
# 22  2024      3           27403
# 23  2024      4           36735

# %%
data = monthly_riders['Monthly Riders']

# %%
decomp = seasonal_decompose(data, period=12)

# %%
plt.figure(figsize=(12, 8))

# Original series
plt.subplot(4, 1, 1)
plt.plot(monthly_riders.index, monthly_riders['Monthly Riders'], label='Original')
plt.title('Original Series')

# Trend component
plt.subplot(4, 1, 2)
plt.plot(decomp.trend.index, decomp.trend, label='Trend')
plt.title('Trend Component')

# Seasonal component
plt.subplot(4, 1, 3)
plt.plot(decomp.seasonal.index, decomp.seasonal, label='Seasonal')
plt.title('Seasonal Component')

# Residual component
plt.subplot(4, 1, 4)
plt.plot(decomp.resid.index, decomp.resid, label='Residual')
plt.title('Residual Component')

plt.tight_layout()
plt.show()

# %%
adfuller_results = adfuller(data)

# %% [markdown]
# #### Test for stationarity

# %%
print('ADF Statistic: %f' % adfuller_results[0])
print('p-value: %f' % adfuller_results[1])
print('Critical Values:')
for key, value in adfuller_results[4].items():
  print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: 0.760045
# p-value: 0.990963
# Critical Values:
# 	1%: -4.012
# 	5%: -3.104
# 	10%: -2.691

# %% [markdown]
# #### differencing

# %%
data.plot()
# Out:
# <Axes: >

# %%
data.diff().plot()
# Out:
# <Axes: >

# %%
data.diff().diff().plot()
# Out:
# <Axes: >

# %%
data.diff().diff().diff().diff().plot()
# Out:
# <Axes: >

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3)
plot_acf(data, ax=ax1)
plot_acf(data.diff().dropna(), ax=ax2)
plot_acf(data.diff().diff().dropna(), ax=ax3)
fig.show()
# Out:
# C:\Users\piggy\AppData\Local\Temp\ipykernel_14392\2450018178.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# d equals 1 or 2

# %%
plot_pacf(data.dropna())
plt.show()

# %%
plot_pacf(data.diff().dropna())
plt.show()

# %%
plot_pacf(data.diff().diff().dropna())
plt.show()

# %% [markdown]
# p equals 1

# %%
plot_acf(data.diff().dropna())
plt.show()

# %% [markdown]
# q = 1

# %%
model = SARIMAX(data, order=(1, 1, 2), seasonal_order=(1,0,1,12))

# %%
results = model.fit()
# Out:
# c:\Users\piggy\Desktop\work\POGOH_Analysis\.venv\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# c:\Users\piggy\Desktop\work\POGOH_Analysis\.venv\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
print(results.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                     Monthly Riders   No. Observations:                   24
# Model:             SARIMAX(1, 1, 1)x(1, 0, 1, 12)   Log Likelihood                -227.531
# Date:                            Sat, 11 May 2024   AIC                            465.062
# Time:                                    23:55:47   BIC                            470.739
# Sample:                                         0   HQIC                           466.490
#                                              - 24
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1416      0.437      0.324      0.746      -0.715       0.999
# ma.L1          0.3693      0.339      1.090      0.276      -0.295       1.033
# ar.S.L12       0.9903      0.104      9.481      0.000       0.786       1.195
# ma.S.L12      -0.8708      0.763     -1.141      0.254      -2.367       0.625
# sigma2      1.509e+07   6.25e-08   2.41e+14      0.000    1.51e+07    1.51e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):                 0.51
# Prob(Q):                              0.88   Prob(JB):                         0.78
# Heteroskedasticity (H):              13.23   Skew:                             0.28
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.46
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.94e+30. Standard errors may be unstable.

# %%
forecast = results.forecast(steps=8)

# %%
forecast
# Out:
# 24    41956.091162
# 25    43923.401349
# 26    45475.994441
# 27    48073.513443
# 28    53313.653271
# 29    52813.495135
# 30    47478.974314
# 31    43070.621994
# Name: predicted_mean, dtype: float64

# %%
forecast = forecast.rename(index={24: 5,
                                  25: 6,
                                  26: 7,
                                  27: 8,
                                  28: 9,
                                  29: 10,
                                  30: 11,
                                  31: 12})

# %%
total_rides_2022 = df[df['Start Date'].dt.year==2022].groupby(df['Start Date'].dt.month).size()
total_rides_2023 = df[df['Start Date'].dt.year==2023].groupby(df['Start Date'].dt.month).size()
total_rides_2024 = df[df['Start Date'].dt.year==2024].groupby(df['Start Date'].dt.month).size()

# %%
forecast[4]=total_rides_2024[4]

# %%
forecast.sort_index(inplace=True)

# %%
plt.figure(figsize=(10, 6))
plt.plot(total_rides_2022.index, total_rides_2022, label='2022')
plt.plot(total_rides_2023.index, total_rides_2023, label='2023')
plt.plot(total_rides_2024.index, total_rides_2024, label='2024')
plt.plot(forecast.index, forecast, label='Potential Ridership')
month_names = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
plt.xticks(np.arange(1, len(month_names)+1), month_names, rotation=45)
plt.legend(fontsize='large', loc='upper left')
plt.grid(True)
plt.title("Monthly Rides (2022 vs 2023 vs 2024)")
plt.xlabel("Month")
plt.ylabel("Total Rides")

plt.scatter(5,6097, color='black')
plt.text(5,5500,'Healthy Ride\nbecomes POGOH', ha='center', va='top')

plt.scatter(6,13505, color='black')
plt.text(6,13000,'Phase 2 Expansion\nCompleted', ha='left', va='top')

plt.scatter(8,23841, color='black')
plt.text(8,23000,'City joins POGOH\npartnership program', ha='left', va='top')
# Out:
# Text(8, 23000, 'City joins POGOH\npartnership program')
