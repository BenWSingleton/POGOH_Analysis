# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
df = pd.read_parquet('./data/POGOH/combined data/data.parquet')

# %%
df
# Out:
#        Closed Status  Duration  Start Station Id          Start Date  \
# 0             NORMAL       257                13 2023-04-30 23:54:00
# 1             NORMAL       351                13 2023-04-30 10:21:00
# 2             NORMAL       310                13 2023-04-30 03:59:00
# 3             NORMAL       408                13 2023-04-30 00:44:00
# 4             NORMAL       417                13 2023-04-29 09:19:00
# ...              ...       ...               ...                 ...
# 939664        NORMAL       823                45 2024-05-18 18:22:40
# 939665        NORMAL       813                45 2024-05-13 19:03:39
# 939666        NORMAL       138                45 2023-11-11 14:14:26
# 939667        NORMAL      1043                45 2023-10-25 19:40:23
# 939668        NORMAL      1304                45 2023-10-16 19:20:32
#
#                    Start Station Name            End Date  End Station Id  \
# ...

# %%
df.shape
# Out:
# (939669, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 939669 entries, 0 to 939668
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Closed Status               939669 non-null  object
#  1   Duration                    939669 non-null  int64
#  2   Start Station Id            939669 non-null  int64
#  3   Start Date                  939669 non-null  datetime64[ns]
#  4   Start Station Name          939669 non-null  object
#  5   End Date                    939669 non-null  datetime64[ns]
#  6   End Station Id              939669 non-null  int64
#  7   End Station Name            939669 non-null  object
#  8   Rider Type                  939669 non-null  object
#  9   Start Station Total Docks   939669 non-null  int64
#  10  Start Station Latitude      939669 non-null  float64
#  11  Start Station Longitude     939669 non-null  float64
# ...

# %%
df['Closed Status'].unique()
# Out:
# array(['NORMAL', 'TERMINATED', 'None', 'FORCED_CLOSED', 'GRACE_PERIOD'],
#       dtype=object)

# %%
df.isna().sum()
# Out:
# Closed Status                 0
# Duration                      0
# Start Station Id              0
# Start Date                    0
# Start Station Name            0
# End Date                      0
# End Station Id                0
# End Station Name              0
# Rider Type                    0
# Start Station Total Docks     0
# Start Station Latitude        0
# Start Station Longitude       0
# Start Station Neighborhood    0
# End Station Total Docks       0
# End Station Latitude          0
# End Station Longitude         0
# End Station Neighborhood      0
# Trip Distance (km)            0
# Trip Time                     0
# dtype: int64

# %%
df['Closed Status'].value_counts()
# Out:
# Closed Status
# NORMAL           887067
# GRACE_PERIOD      44875
# None               6097
# FORCED_CLOSED      1026
# TERMINATED          604
# Name: count, dtype: int64

# %%
df['Trip Distance (km)'].mean()
# Out:
# 1.2683204350660542

# %%
df['Trip Distance (km)'].median()
# Out:
# 0.8740520972080654

# %%
df['Trip Distance (km)'].hist(bins=100)
# Out:
# <Axes: >

# %%
df['Start Station Name'].value_counts()
# Out:
# Start Station Name
# S Bouquet Ave & Sennott St                85108
# Boulevard of the Allies & Parkview Ave    62428
# Atwood St & Bates St                      51727
# N Dithridge St & Centre Ave               49727
# Forbes Ave & Schenley Dr                  43519
#                                           ...
# Eliza St & Lytle St                         647
# Second Ave & Tecumseh St                    552
# N Braddock Ave & Hamilton Ave               466
# N Braddock Ave & Frankstown Ave             185
# Bennett St & N Homewood Ave                  86
# Name: count, Length: 64, dtype: int64

# %%
df
# Out:
#        Closed Status  Duration  Start Station Id          Start Date  \
# 0             NORMAL       257                13 2023-04-30 23:54:00
# 1             NORMAL       351                13 2023-04-30 10:21:00
# 2             NORMAL       310                13 2023-04-30 03:59:00
# 3             NORMAL       408                13 2023-04-30 00:44:00
# 4             NORMAL       417                13 2023-04-29 09:19:00
# ...              ...       ...               ...                 ...
# 939664        NORMAL       823                45 2024-05-18 18:22:40
# 939665        NORMAL       813                45 2024-05-13 19:03:39
# 939666        NORMAL       138                45 2023-11-11 14:14:26
# 939667        NORMAL      1043                45 2023-10-25 19:40:23
# 939668        NORMAL      1304                45 2023-10-16 19:20:32
#
#                    Start Station Name            End Date  End Station Id  \
# ...

# %%
df[df['Start Date'].dt.year==2024]
# Out:
#        Closed Status  Duration  Start Station Id          Start Date  \
# 78            NORMAL       498                13 2024-04-30 22:23:00
# 79            NORMAL       275                13 2024-04-30 14:26:00
# 80            NORMAL       602                13 2024-04-29 19:00:00
# 81            NORMAL       665                13 2024-04-28 23:58:00
# 82            NORMAL       330                13 2024-04-28 20:22:00
# ...              ...       ...               ...                 ...
# 939661        NORMAL       861                45 2024-06-15 17:04:49
# 939662        NORMAL      1811                45 2024-06-05 12:20:52
# 939663        NORMAL      1375                45 2024-05-31 09:14:35
# 939664        NORMAL       823                45 2024-05-18 18:22:40
# 939665        NORMAL       813                45 2024-05-13 19:03:39
#
#                    Start Station Name            End Date  End Station Id  \
# ...

# %%
df['Rider Type'].value_counts()
# Out:
# Rider Type
# MEMBER    828647
# CASUAL    111022
# Name: count, dtype: int64

# %%
df['Closed Status'].value_counts()
# Out:
# Closed Status
# NORMAL           887067
# GRACE_PERIOD      44875
# None               6097
# FORCED_CLOSED      1026
# TERMINATED          604
# Name: count, dtype: int64

# %%
df[df['Closed Status']=='TERMINATED']
# Out:
#        Closed Status  Duration  Start Station Id          Start Date  \
# 676       TERMINATED      1080                13 2022-08-15 11:32:49
# 5935      TERMINATED      9666                17 2024-11-08 14:25:54
# 8737      TERMINATED     89987                35 2024-04-16 15:17:00
# 13841     TERMINATED         0                12 2024-07-25 15:21:01
# 14139     TERMINATED         0                12 2022-06-07 13:08:06
# ...              ...       ...               ...                 ...
# 938701    TERMINATED      1798                58 2025-03-29 18:10:02
# 938776    TERMINATED         0                39 2024-05-31 18:43:40
# 939091    TERMINATED     62788                14 2024-03-03 16:20:32
# 939117    TERMINATED       897                30 2024-03-07 02:10:03
# 939157    TERMINATED      1204                48 2024-03-03 01:16:56
#
#                     Start Station Name            End Date  End Station Id  \
# ...

# %%
df['Start Station Name'].value_counts().head(10)
# Out:
# Start Station Name
# S Bouquet Ave & Sennott St                85108
# Boulevard of the Allies & Parkview Ave    62428
# Atwood St & Bates St                      51727
# N Dithridge St & Centre Ave               49727
# Forbes Ave & Schenley Dr                  43519
# Zulema St & Coltart Ave                   39964
# O'Hara St and University Place            39469
# Fifth Ave & S Bouquet St                  38211
# Coltart Ave & Forbes Ave                  32223
# Allequippa St & Darragh St                31802
# Name: count, dtype: int64

# %%
df['Start Station Name'].value_counts().tail(10)
# Out:
# Start Station Name
# Centre Ave & Heldman St            1469
# Tioga St & N Homewood Ave          1308
# Hamilton Ave & Fifth Ave           1302
# Bedford Ave & Memory Ln            1176
# Wilkinsburg Park & Ride             743
# Eliza St & Lytle St                 647
# Second Ave & Tecumseh St            552
# N Braddock Ave & Hamilton Ave       466
# N Braddock Ave & Frankstown Ave     185
# Bennett St & N Homewood Ave          86
# Name: count, dtype: int64

# %%
df['End Station Name'].value_counts().head(10)
# Out:
# End Station Name
# S Bouquet Ave & Sennott St                  87099
# Boulevard of the Allies & Parkview Ave      60985
# Atwood St & Bates St                        50238
# Forbes Ave & Schenley Dr                    45637
# N Dithridge St & Centre Ave                 44541
# Zulema St & Coltart Ave                     41925
# O'Hara St and University Place              41633
# Fifth Ave & S Bouquet St                    37648
# Coltart Ave & Forbes Ave                    31788
# S 27th St & Sidney St. (Southside Works)    29425
# Name: count, dtype: int64

# %%
df['End Station Name'].value_counts().tail(10)
# Out:
# End Station Name
# Centre Ave & Heldman St            1415
# Hamilton Ave & Fifth Ave           1332
# Rosetta St & N Aiken Ave           1275
# Wilkinsburg Park & Ride            1040
# Bedford Ave & Memory Ln             784
# Second Ave & Tecumseh St            670
# Eliza St & Lytle St                 625
# N Braddock Ave & Hamilton Ave       554
# N Braddock Ave & Frankstown Ave     213
# Bennett St & N Homewood Ave          78
# Name: count, dtype: int64

# %%
df['Start Station Neighborhood'].value_counts()
# Out:
# Start Station Neighborhood
# Central Oakland          271450
# North Oakland            187508
# Downtown                  75812
# Shadyside                 59865
# South Side Flats          52623
# Bloomfield                51277
# West Oakland              38211
# Strip District            32419
# Terrace Village           31802
# Friendship                16636
# North Shore               16397
# Lower Lawrenceville       16115
# South Shore               14265
# Allegheny Center          11268
# East Liberty              10960
# Central Lawrenceville     10573
# South Oakland             10170
# Hazelwood                  9203
# Chateau                    5976
# Upper Lawrenceville        4309
# Central Northside          2529
# Middle Hill                2096
# Homewood South             1774
# Garfield                   1470
# Crawford-Roberts           1469
# Larimer                    1302
# Hill District              1176
# Wilkinsburg                 743
# ...

# %%
df[(df['Start Station Neighborhood']=='Central Oakland') & (df['Start Date'].dt.year==2024)]
# Out:
#        Closed Status  Duration  Start Station Id          Start Date  \
# 78            NORMAL       498                13 2024-04-30 22:23:00
# 79            NORMAL       275                13 2024-04-30 14:26:00
# 80            NORMAL       602                13 2024-04-29 19:00:00
# 81            NORMAL       665                13 2024-04-28 23:58:00
# 82            NORMAL       330                13 2024-04-28 20:22:00
# ...              ...       ...               ...                 ...
# 938868        NORMAL      1144                20 2024-06-05 12:39:18
# 938869        NORMAL      1300                20 2024-05-20 20:43:16
# 938870        NORMAL      1302                20 2024-05-20 20:43:14
# 939141        NORMAL      2030                51 2024-08-10 22:25:11
# 939149        NORMAL      2646                50 2024-10-24 15:07:18
#
#                             Start Station Name            End Date  \
# 78                  S Bouquet Ave & Sennott St 2024-04-30 22:31:00
# ...

# %%
df[((df['Start Station Neighborhood']=='Strip District') | (df['End Station Neighborhood']=='Strip District'))  & (df['Start Date'].dt.year==2024)]
# Out:
#        Closed Status  Duration  Start Station Id          Start Date  \
# 34636         NORMAL      1143                 4 2024-12-15 09:13:47
# 34637         NORMAL       842                 4 2024-12-08 09:15:52
# 34638         NORMAL      1064                 4 2024-12-04 18:27:32
# 34640         NORMAL       961                 4 2024-02-01 20:11:46
# 34641         NORMAL       957                 4 2024-02-01 20:11:46
# ...              ...       ...               ...                 ...
# 938649        NORMAL      3266                47 2024-09-18 19:10:07
# 938650        NORMAL       987                47 2024-09-13 19:12:43
# 938651        NORMAL      1099                47 2024-09-09 22:59:29
# 938944        NORMAL      5141                 4 2024-07-13 22:15:48
# 939060        NORMAL      2119                18 2024-10-15 13:14:50
#
#                        Start Station Name            End Date  End Station Id  \
# ...

# %%
df['End Station Neighborhood'].value_counts()
# Out:
# End Station Neighborhood
# Central Oakland          272034
# North Oakland            188207
# Downtown                  76531
# Shadyside                 60712
# South Side Flats          56825
# Bloomfield                49163
# West Oakland              37648
# Strip District            33611
# Terrace Village           22006
# Friendship                17263
# North Shore               16914
# Lower Lawrenceville       16133
# South Shore               14161
# Allegheny Center          11597
# South Oakland             11425
# East Liberty              11206
# Central Lawrenceville     11179
# Hazelwood                  9371
# Chateau                    6411
# Upper Lawrenceville        4685
# Central Northside          2599
# Homewood South             2009
# Middle Hill                1843
# Crawford-Roberts           1415
# Larimer                    1332
# Garfield                   1274
# Wilkinsburg                1040
# Hill District               784
# ...

# %%
set(df['Start Station Neighborhood'].unique().tolist()).intersection(set(df['End Station Neighborhood'].unique().tolist()))
# Out:
# {'Allegheny Center',
#  'Bloomfield',
#  'Central Lawrenceville',
#  'Central Northside',
#  'Central Oakland',
#  'Chateau',
#  'Crawford-Roberts',
#  'Downtown',
#  'East Liberty',
#  'Friendship',
#  'Garfield',
#  'Hazelwood',
#  'Hill District',
#  'Homewood North',
#  'Homewood South',
#  'Larimer',
#  'Lower Lawrenceville',
#  'Middle Hill',
#  'North Oakland',
#  'North Shore',
#  'Shadyside',
#  'South Oakland',
#  'South Shore',
#  'South Side Flats',
#  'Strip District',
#  'Terrace Village',
#  'Upper Lawrenceville',
#  'West Oakland',
#  'Wilkinsburg'}

# %% [markdown]
# ## Total trips to or through the strip district

# %% [markdown]
# #### starting or ending in the strip

# %%
df[(df['Start Date'].dt.year.isin([2023])) & ((df['Start Station Neighborhood']=='Strip District') | (df['End Station Neighborhood']=='Strip District'))]
# Out:
#        Closed Status  Duration  Start Station Id          Start Date  \
# 34634         NORMAL      1039                 4 2023-12-23 18:12:13
# 34635         NORMAL       850                 4 2023-12-17 14:18:02
# 34639         NORMAL       857                 4 2023-02-16 15:03:51
# 34650         NORMAL       916                 4 2023-03-23 12:50:47
# 34651         NORMAL       894                 4 2023-03-02 14:54:28
# ...              ...       ...               ...                 ...
# 938631        NORMAL      1672                47 2023-10-28 21:28:40
# 938632        NORMAL       666                47 2023-10-25 19:21:52
# 938633        NORMAL       969                47 2023-10-13 17:58:30
# 938643        NORMAL      4303                47 2023-09-02 15:20:19
# 938644        NORMAL      4372                47 2023-09-02 15:18:43
#
#                        Start Station Name            End Date  End Station Id  \
# ...

# %%
df[(df['Start Date'].dt.year==2024) & (df['Start Date'].dt.month==4)]['Start Date'].dt.day.max()
# Out:
# 30

# %%
strip_district_data = df[((df['Start Station Neighborhood'] == 'Strip District') | (df['End Station Neighborhood'] == 'Strip District'))& 
                         (df['Start Date'].dt.year.isin([2023, 2024, 2025]))]

# %%
grouped_data = strip_district_data.groupby(strip_district_data['Start Date'].dt.date).size()

# %%
grouped_data.index = pd.to_datetime(grouped_data.index)

# %%
cumulative_rides_2023 = grouped_data[grouped_data.index.year == 2023].cumsum()
cumulative_rides_2024 = grouped_data[grouped_data.index.year == 2024].cumsum()
cumulative_rides_2025 = grouped_data[grouped_data.index.year == 2025].cumsum()

# %%
monthFmt = mdates.DateFormatter('%b')

# %%
plt.figure(figsize=(10, 6))
plt.plot(cumulative_rides_2025.index.dayofyear, cumulative_rides_2025, label='2025')
plt.plot(cumulative_rides_2024.index.dayofyear, cumulative_rides_2024, label='2024')
plt.plot(cumulative_rides_2023.index.dayofyear, cumulative_rides_2023, label='2023')
plt.legend(fontsize='large')
plt.xlabel("Month")
plt.ylabel("Number of Trips")
plt.grid(True)
plt.title("Cumulative POGOH Rides to and from the Strip (2023 vs 2024)")
plt.gca().xaxis.set_major_formatter(monthFmt)

# %%
total_rides_2022 = df[df['Start Date'].dt.year==2022].groupby(df['Start Date'].dt.month).size()
total_rides_2023 = df[df['Start Date'].dt.year==2023].groupby(df['Start Date'].dt.month).size()
total_rides_2024 = df[df['Start Date'].dt.year==2024].groupby(df['Start Date'].dt.month).size()
total_rides_2025 = df[df['Start Date'].dt.year==2025].groupby(df['Start Date'].dt.month).size()

# %%
plt.figure(figsize=(10, 6))
plt.plot(total_rides_2022.index, total_rides_2022, label='2022')
plt.plot(total_rides_2023.index, total_rides_2023, label='2023')
plt.plot(total_rides_2024.index, total_rides_2024, label='2024')
plt.plot(total_rides_2025.index, total_rides_2025, label='2025')
month_names = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
plt.xticks(np.arange(1, len(month_names)+1), month_names, rotation=45)
plt.legend(fontsize='large', loc='upper left')
plt.grid(True)
plt.title("Monthly Rides (2022 vs 2023 vs 2024 vs 2025)")
plt.xlabel("Month")
plt.ylabel("Total Rides")

plt.scatter(5,6097, color='black')
plt.text(5,5500,'Healthy Ride\nbecomes POGOH', ha='center', va='top')

plt.scatter(6,13505, color='black')
plt.text(6,13000,'Phase 2 Expansion\nCompleted', ha='left', va='top')

plt.scatter(8,23841, color='black')
plt.text(8,23000,'City joins POGOH\npartnership program', ha='left', va='top')
# Out:
# Text(8, 23000, 'City joins POGOH\npartnership program')

# %%
df[(df['Start Date'].dt.year==2023) & (df['Start Date'].dt.month==8)].shape
# Out:
# (23841, 19)

# %%
total_strip_rides_2022 = df[(df['Start Date'].dt.year==2022) & ((df['Start Station Neighborhood']=='Strip District') | (df['End Station Neighborhood']=='Strip District'))].groupby(df['Start Date'].dt.month).size()
total_strip_rides_2023 = df[(df['Start Date'].dt.year==2023) & ((df['Start Station Neighborhood']=='Strip District') | (df['End Station Neighborhood']=='Strip District'))].groupby(df['Start Date'].dt.month).size()
total_strip_rides_2024 = df[(df['Start Date'].dt.year==2024) & ((df['Start Station Neighborhood']=='Strip District') | (df['End Station Neighborhood']=='Strip District'))].groupby(df['Start Date'].dt.month).size()
total_strip_rides_2025 = df[(df['Start Date'].dt.year==2025) & ((df['Start Station Neighborhood']=='Strip District') | (df['End Station Neighborhood']=='Strip District'))].groupby(df['Start Date'].dt.month).size()

# %%
plt.figure(figsize=(10, 6))
plt.plot(total_strip_rides_2022.index, total_strip_rides_2022, label='2022')
plt.plot(total_strip_rides_2023.index, total_strip_rides_2023, label='2023')
plt.plot(total_strip_rides_2024.index, total_strip_rides_2024, label='2024')
plt.plot(total_strip_rides_2025.index, total_strip_rides_2025, label='2025')
month_names = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
plt.xticks(np.arange(1, len(month_names)+1), month_names, rotation=45)
plt.legend(fontsize='large')
plt.grid(True)
plt.title("Monthly Station Usage in the Strip (2022 vs 2023 vs 2024)")
plt.xlabel("Month")
plt.ylabel("Total Rides")
# Out:
# Text(0, 0.5, 'Total Rides')

# %%
total_oakland_rides_2022 = df[(df['Start Date'].dt.year==2022) & ((df['Start Station Neighborhood'].str.contains('Oakland')) | (df['End Station Neighborhood'].str.contains('Oakland')))].groupby(df['Start Date'].dt.month).size()
total_oakland_rides_2023 = df[(df['Start Date'].dt.year==2023) & ((df['Start Station Neighborhood'].str.contains('Oakland')) | (df['End Station Neighborhood'].str.contains('Oakland')))].groupby(df['Start Date'].dt.month).size()
total_oakland_rides_2024 = df[(df['Start Date'].dt.year==2024) & ((df['Start Station Neighborhood'].str.contains('Oakland')) | (df['End Station Neighborhood'].str.contains('Oakland')))].groupby(df['Start Date'].dt.month).size()

# %%
plt.figure(figsize=(10, 6))
plt.plot(total_oakland_rides_2022.index, total_oakland_rides_2022, label='2022')
plt.plot(total_oakland_rides_2023.index, total_oakland_rides_2023, label='2023')
plt.plot(total_oakland_rides_2024.index, total_oakland_rides_2024, label='2024')
month_names = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
plt.xticks(np.arange(1, len(month_names)+1), month_names, rotation=45)
plt.legend(fontsize='large')
plt.grid(True)
plt.title("Monthly Station Usage in Oakland (2022 vs 2023 vs 2024)")
plt.xlabel("Month")
plt.ylabel("Total Rides")
# Out:
# Text(0, 0.5, 'Total Rides')

# %%
total_strip_rides_2023 = df[(df['Start Date'].dt.year==2023) & (df['Start Date'].dt.month>=6) & ((df['Start Station Neighborhood']=='Strip District') | (df['End Station Neighborhood']=='Strip District'))].groupby(df['Start Date'].dt.month).size()
total_strip_rides_2024 = df[(df['Start Date'].dt.year==2024) & (df['Start Date'].dt.month<=6) & ((df['Start Station Neighborhood']=='Strip District') | (df['End Station Neighborhood']=='Strip District'))].groupby(df['Start Date'].dt.month).size()

# %%
total_strip_rides_2023
# Out:
# Start Date
# 6     1324
# 7     1872
# 8     1963
# 9     1950
# 10    1307
# 11     951
# 12     799
# dtype: int64

# %%
total_strip_rides_2024
# Out:
# Start Date
# 1     452
# 2     705
# 3    1172
# 4    1723
# 5    2709
# 6    2989
# dtype: int64

# %%
report_series_1 = pd.Series(total_strip_rides_2023.values.tolist() + [452], [1,2,3,4,5,6,7,8])
report_series_2 = pd.Series(total_strip_rides_2024.values.tolist(), [8,9,10,11,12,13])

# %%
plt.figure(figsize=(10, 4))
plt.plot(report_series_1.index, report_series_1, label='2023')
plt.plot(report_series_2.index, report_series_2, label='2024')
month_names = ['June 2023', 'July 2023', 'August 2023', 'September 2023', 'October 2023', 'November 2023', 'December 2024', 'January 2024', 'February 2024', 'March 2024', 'April 2024', 'May 2024', 'June 2024']
plt.xticks(np.arange(1, len(month_names)+1), month_names, rotation=45)
plt.legend(fontsize='large')
plt.grid(True)
plt.title("Strip District POGOH Station Usage (June 2023 - June 2024)")
plt.xlabel("Month")
plt.ylabel("Total Rides")
# Out:
# Text(0, 0.5, 'Total Rides')

# %% [markdown]
# #### trips that almost certaintly went through the strip

# %%
set1 = ['Downtown', 'North Shore', 'Allegheny Center', 'Chateau', 'Central Northside', 'South Shore']
set2 = ['Lower Lawrenceville', 'Central Lawrenceville', 'Upper Lawrenceville', 'Bloomfield', 'Garfield', 'Shadyside', 'Friendship', 'East Liberty', 'Larimer']

# %%
df[((df['Start Date'].dt.year.isin([2023])) & (df['Start Station Neighborhood'].isin(set1)) & (df['End Station Neighborhood'].isin(set2))) | 
   ((df['Start Date'].dt.year.isin([2023])) & (df['Start Station Neighborhood'].isin(set2)) & (df['End Station Neighborhood'].isin(set1))) |
   (df['Start Station Neighborhood']=='Strip District') & (df['Start Date'].dt.year==2023) | 
   (df['End Station Neighborhood']=='Strip District') & (df['Start Date'].dt.year==2023)]
# Out:
#        Closed Status  Duration  Start Station Id          Start Date  \
# 34634         NORMAL      1039                 4 2023-12-23 18:12:13
# 34635         NORMAL       850                 4 2023-12-17 14:18:02
# 34639         NORMAL       857                 4 2023-02-16 15:03:51
# 34650         NORMAL       916                 4 2023-03-23 12:50:47
# 34651         NORMAL       894                 4 2023-03-02 14:54:28
# ...              ...       ...               ...                 ...
# 938631        NORMAL      1672                47 2023-10-28 21:28:40
# 938632        NORMAL       666                47 2023-10-25 19:21:52
# 938633        NORMAL       969                47 2023-10-13 17:58:30
# 938643        NORMAL      4303                47 2023-09-02 15:20:19
# 938644        NORMAL      4372                47 2023-09-02 15:18:43
#
#                        Start Station Name            End Date  End Station Id  \
# ...

# %%
total_strip_through_rides_2022 = df[(df['Start Date'].dt.year==2022) & ((df['Start Station Neighborhood']=='Strip District') | (df['End Station Neighborhood']=='Strip District') | ((df['Start Station Neighborhood'].isin(set1)) & (df['End Station Neighborhood'].isin(set2))) | ((df['Start Station Neighborhood'].isin(set2)) & (df['End Station Neighborhood'].isin(set1))))].groupby(df['Start Date'].dt.month).size()
total_strip_through_rides_2023 = df[(df['Start Date'].dt.year==2023) & ((df['Start Station Neighborhood']=='Strip District') | (df['End Station Neighborhood']=='Strip District') | ((df['Start Station Neighborhood'].isin(set1)) & (df['End Station Neighborhood'].isin(set2))) | ((df['Start Station Neighborhood'].isin(set2)) & (df['End Station Neighborhood'].isin(set1))))].groupby(df['Start Date'].dt.month).size()
total_strip_through_rides_2024 = df[(df['Start Date'].dt.year==2024) & ((df['Start Station Neighborhood']=='Strip District') | (df['End Station Neighborhood']=='Strip District') | ((df['Start Station Neighborhood'].isin(set1)) & (df['End Station Neighborhood'].isin(set2))) | ((df['Start Station Neighborhood'].isin(set2)) & (df['End Station Neighborhood'].isin(set1))))].groupby(df['Start Date'].dt.month).size()

# %%
print(total_strip_through_rides_2022.sum())
print(total_strip_through_rides_2023.sum())
print(total_strip_through_rides_2024.sum())
# Out:
# 9778
# 19526
# 36348

# %%
plt.figure(figsize=(10, 6))
plt.plot(total_strip_through_rides_2022.index, total_strip_through_rides_2022, label='2022')
plt.plot(total_strip_through_rides_2023.index, total_strip_through_rides_2023, label='2023')
plt.plot(total_strip_through_rides_2024.index, total_strip_through_rides_2024, label='2024')
month_names = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
plt.xticks(np.arange(1, len(month_names)+1), month_names, rotation=45)
plt.legend(fontsize='large')
plt.grid(True)
plt.title("Rides in and Through the Strip (2022 vs 2023 vs 2024)")
plt.xlabel("Month")
plt.ylabel("Total Rides")
# Out:
# Text(0, 0.5, 'Total Rides')

# %% [markdown]
# #### Station Analysis

# %%
stations_2024 = df[(df['Start Date'].dt.year==2024) & ((df['Start Station Neighborhood']=='Strip District') | (df['End Station Neighborhood']=='Strip District'))][['Start Station Name', 'End Station Name']]
stations_2025 = df[(df['Start Date'].dt.year==2025) & ((df['Start Station Neighborhood']=='Strip District') | (df['End Station Neighborhood']=='Strip District'))][['Start Station Name', 'End Station Name']]

# %%
pd.concat([stations_2025['Start Station Name'], stations_2025['End Station Name']]).value_counts()
# Out:
# 21st St & Penn Ave                          4789
# 17th St & Penn Ave                          4318
# Burns White Center at 3 Crossings           3991
# 10th St & Penn Ave                          1538
# 7th St & Penn Ave                            649
# Forbes Ave & Market Square                   593
# Penn Ave & 7th St                            584
# Butler St & 36th St                          557
# W North Ave & Federal St                     487
# Penn Ave & 33rd St                           470
# North Shore Trail & Fort Duquesne Bridge     439
# Liberty Ave & Stanwix St                     418
# Ross St & Fourth Ave                         390
# 42nd St & Butler St                          315
# Liberty Ave & Gross St                       291
# Taylor St & Liberty Ave                      232
# First Ave & B St                             206
# Glasshouse                                   196
# 52nd St & Butler St                          184
# ...

# %%
pd.concat([stations_2025['Start Station Name'], stations_2025['End Station Name']]).value_counts().sum()
# Out:
# 23344

# %%
strip_stations = df[df['Start Station Neighborhood']=='Strip District']['Start Station Name'].unique().tolist()

# %%
station_usage_start = df[(df['Start Date'].dt.year==2024) & ((df['Start Station Neighborhood']=='Strip District') & (df['End Station Neighborhood']!='Strip District'))]['Start Station Name'].value_counts()

# %%
station_usage_end = df[(df['Start Date'].dt.year==2024) & ((df['Start Station Neighborhood']!='Strip District') & (df['End Station Neighborhood']=='Strip District'))]['End Station Name'].value_counts()

# %%
station_usage_both = df[(df['Start Date'].dt.year==2024) & ((df['Start Station Neighborhood']=='Strip District') & (df['End Station Neighborhood']=='Strip District'))][['Start Station Name', 'End Station Name']].value_counts()

# %%
station_usage_both
# Out:
# Start Station Name                 End Station Name
# 21st St & Penn Ave                 21st St & Penn Ave                   888
# 17th St & Penn Ave                 17th St & Penn Ave                   672
# Burns White Center at 3 Crossings  Burns White Center at 3 Crossings    639
#                                    21st St & Penn Ave                   549
# 21st St & Penn Ave                 Burns White Center at 3 Crossings    390
#                                    17th St & Penn Ave                   265
# Burns White Center at 3 Crossings  17th St & Penn Ave                   264
# 17th St & Penn Ave                 Burns White Center at 3 Crossings    191
#                                    21st St & Penn Ave                   176
# Name: count, dtype: int64

# %%
(station_usage_start + station_usage_end).sort_values(ascending=False).sum()
# Out:
# 21891

# %%
total_strip_rides_2024.sum()
# Out:
# 9750

# %%
df[(df['Start Date'].dt.year==2024) & ((df['Start Station Neighborhood']=='Strip District'))].groupby(df['Start Date'].dt.month).size().sum()
# Out:
# 14819

# %%
df[(df['Start Date'].dt.year==2024) & ((df['End Station Neighborhood']=='Strip District'))].groupby(df['Start Date'].dt.month).size().sum()
# Out:
# 15140

# %%
df[(df['Start Date'].dt.year==2024) & ((df['Start Station Neighborhood']=='Strip District') | (df['End Station Neighborhood']=='Strip District'))].groupby(df['Start Date'].dt.month).size().sum()
# Out:
# 25925

# %%
df[((df['Start Date'].dt.year==2024) & (df['Start Station Neighborhood']=='Strip District')) | 
   ((df['Start Date'].dt.year==2024) & (df['End Station Neighborhood']=='Strip District'))].groupby(df['Start Date'].dt.month).size().sum()
# Out:
# 25925

# %%
df[(df['Start Date'].dt.year==2024) & ((df['Start Station Neighborhood']=='Strip District') & (df['End Station Neighborhood']=='Strip District'))].groupby(df['Start Date'].dt.month).size().sum()
# Out:
# 4034
