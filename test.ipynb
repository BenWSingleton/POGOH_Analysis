# %%
import data_ingestion

# %%
df = data_ingestion.process_data()
# Out:
# c:\Users\piggy\Desktop\work\POGOH_Analysis\data_ingestion.py:124: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Start Date'] = pd.to_datetime(df['Start Date'])
# c:\Users\piggy\Desktop\work\POGOH_Analysis\data_ingestion.py:125: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['End Date'] = pd.to_datetime(df['End Date'])

# %%
df
# Out:
#        Closed Status  Duration  Start Station Id          Start Date  \
# 0             NORMAL       257                13 2023-04-30 23:54:00
# 1             NORMAL       310                37 2023-04-30 23:35:00
# 2             NORMAL       331                 7 2023-04-30 23:33:00
# 3             NORMAL       345                13 2023-04-30 23:08:00
# 4             NORMAL      1714                17 2023-04-30 23:06:00
# ...              ...       ...               ...                 ...
# 939679        NORMAL       443                12 2024-09-01 00:06:29
# 939680        NORMAL      1759                51 2024-09-01 00:06:24
# 939681        NORMAL      1815                51 2024-09-01 00:05:57
# 939682        NORMAL       364                10 2024-09-01 00:03:04
# 939683        NORMAL      4429                21 2024-09-01 00:00:28
#
#                     Start Station Name            End Date  End Station Id  \
# ...

# %%
df['Start Date'].dtype
# Out:
# dtype('<M8[ns]')
